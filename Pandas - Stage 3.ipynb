# %% [markdown]
# Import pandas to your codebase

# %%
import pandas as pd

# %% [markdown]
# Read the CSV file

# %%
df = pd.read_csv('data/Churn1 (Comma).csv')
df
# Out:
#      Customer State  Account Length  Area Code     Phone Int'l Plan  \
# 0       A1001    KS           128.0        415  382-4657         no
# 1       A1002    OH           107.0        415  371-7191         no
# 2       A1003    NJ           137.0        415  358-1921         no
# 3       A1004    OH            84.0        408  375-9999        yes
# 4       A1005    OK            75.0        415  330-6626        yes
# 5       A1006    AL             NaN        510  391-8027        yes
# 6       A1007    MA             NaN        510  355-9993         no
# 7       A1008    MO           147.0        415  329-9001        yes
# 8       A1009    LA           117.0        408  335-4719         no
# 9       A1004    OH            84.0        408  375-9999        yes
# 10      A1010    WV           141.0        415  330-8173        yes
# 11      A1011    IN             NaN        415  329-6603         no
# 12      A1012    RI            74.0        415  344-9403         no
# ...

# %% [markdown]
# What is the break down of customer service calls by count

# %%
df.groupby('CustServ Calls')['CustServ Calls'].count()
# Out:
# CustServ Calls
# 0     697
# 1    1181
# 2     760
# 3     429
# 4     166
# 5      66
# 6      22
# 7       9
# 8       2
# 9       2
# Name: CustServ Calls, dtype: int64

# %% [markdown]
# GroupBy multiple columns

# %%
df.groupby(['CustServ Calls','Churn?'])

# %%
max = df['Account Length'].quantile(.9)
min = df['Account Length'].quantile(.1)
print(max)
print(min)
# This dataframe gives you records which fall within your outlier
df[(df['Account Length'] > min) & (df['Account Length'] < max )]
# Out:
# 152.0
# 50.0
#      Customer State  Account Length  Area Code     Phone Int'l Plan  \
# 0       A1001    KS           128.0        415  382-4657         no
# 1       A1002    OH           107.0        415  371-7191         no
# 2       A1003    NJ           137.0        415  358-1921         no
# 3       A1004    OH            84.0        408  375-9999        yes
# 4       A1005    OK            75.0        415  330-6626        yes
# 7       A1008    MO           147.0        415  329-9001        yes
# 8       A1009    LA           117.0        408  335-4719         no
# 9       A1004    OH            84.0        408  375-9999        yes
# 10      A1010    WV           141.0        415  330-8173        yes
# 12      A1012    RI            74.0        415  344-9403         no
# 14      A1014    MT            95.0        510  394-8006         no
# 15      A1015    IA            62.0        415  366-9238         no
# 17      A1017    ID            85.0        408  350-8884         no
# ...

# %%
df['Account Length'].quantile

# %% [markdown]
# Drop the outliers by percentile (5% Account Length)

# %%
df.dtypes
# Out:
# Customer           object
# State              object
# Account Length    float64
# Area Code           int64
# Phone              object
# Int'l Plan         object
# VMail Plan         object
# VMail Message     float64
# Day Mins          float64
# Day Calls           int64
# Day Charge        float64
# Eve Mins          float64
# Eve Calls           int64
# Eve Charge        float64
# Night Mins        float64
# Night Calls         int64
# Night Charge      float64
# Intl Mins         float64
# Intl Calls          int64
# Intl Charge       float64
# CustServ Calls      int64
# Churn?             object
# dtype: object

# %% [markdown]
# Replace NA by mean

# %%
df.isna().sum()
#df.fillna(df.mean(),inplace=True)
df.isna().sum()
df.dropna(axis=0,how='any', inplace=True)

# %% [markdown]
# Drop duplicates

# %%
#df.duplicated()
df.drop_duplicates(keep='last')
# Out:
#      Customer State  Account Length  Area Code     Phone Int'l Plan  \
# 0       A1001    KS      128.000000        415  382-4657         no
# 1       A1002    OH      107.000000        415  371-7191         no
# 2       A1003    NJ      137.000000        415  358-1921         no
# 4       A1005    OK       75.000000        415  330-6626        yes
# 5       A1006    AL      101.059442        510  391-8027        yes
# 6       A1007    MA      101.059442        510  355-9993         no
# 7       A1008    MO      147.000000        415  329-9001        yes
# 8       A1009    LA      117.000000        408  335-4719         no
# 9       A1004    OH       84.000000        408  375-9999        yes
# 10      A1010    WV      141.000000        415  330-8173        yes
# 11      A1011    IN      101.059442        415  329-6603         no
# 12      A1012    RI       74.000000        415  344-9403         no
# 13      A1013    IA      168.000000        408  363-1107         no
# ...

# %% [markdown]
# Cut the data frame by multiple bins

# %%
pd.cut(df['Account Length'],[1,50,100,150,200,250],labels=["smallest", "hundred", "one fifties","two hundreds","biggest"])
# Out:
# 2        one fifties
# 3            hundred
# 4            hundred
# 7        one fifties
# 8        one fifties
# 9            hundred
# 12           hundred
# 13      two hundreds
# 14           hundred
# 15           hundred
# 16      two hundreds
# 17           hundred
# 18           hundred
# 19           hundred
# 20           hundred
# 21       one fifties
# 22           hundred
# 23       one fifties
# 24       one fifties
# 25       one fifties
# 26      two hundreds
# 27           hundred
# 28           hundred
# 29          smallest
# 30          smallest
# 31       one fifties
# 32           hundred
# 33      two hundreds
# 34          smallest
# 35           hundred
#             ...
# 3304     one fifties
# 3305         hundred
# 3306         hundred
# 3307     one fifties
# 3308    two hundreds
# 3309        smallest
# 3310         hundred
# 3311         hundred
# 3312     one fifties
# 3313    two hundreds
# 3314     one fifties
# 3315         hundred
# ...

# %% [markdown]
# Export the dataframe to csv

# %%
df.to_csv('output.csv')
