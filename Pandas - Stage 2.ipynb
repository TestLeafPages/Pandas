# %% [markdown]
# Import pandas to your codebase

# %%
import pandas as pd

# %% [markdown]
# Read the CSV file

# %%
df = pd.read_csv('data/Churn1 (Comma).csv')
df.loc[181:182]
# Out:
#     Customer State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 181    A1182    AK           126.0        415  372-3750         no         no
# 182    A1183    NY            67.0        408  405-2888         no        yes
#
#      VMail Message  Day Mins  Day Calls  ...  Eve Calls  Eve Charge  \
# 181              0      58.2         94  ...        118       11.79
# 182             36     115.6        111  ...         94       20.20
#
#      Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 181       136.8           91          6.16       11.9           1
# 182       169.9          103          7.65        9.9          12
#
#      Intl Charge  CustServ Calls  Churn?
# 181         3.21               5   True.
# 182         2.67               2  False.
#
# [2 rows x 22 columns]

# %% [markdown]
# List all columns

# %%
df.columns
# Out:
# Index(['Customer', 'State', 'Account Length', 'Area Code', 'Phone',
#        'Int'l Plan', 'VMail Plan', 'VMail Message', 'Day Mins', 'Day Calls',
#        'Day Charge', 'Eve Mins', 'Eve Calls', 'Eve Charge', 'Night Mins',
#        'Night Calls', 'Night Charge', 'Intl Mins', 'Intl Calls', 'Intl Charge',
#        'CustServ Calls', 'Churn?'],
#       dtype='object')

# %% [markdown]
# Add a new column 'Total Minutes'

# %%
df['Total Minutes'] = 0
df.dtypes
# Out:
# Customer           object
# State              object
# Account Length    float64
# Area Code           int64
# Phone              object
# Int'l Plan         object
# VMail Plan         object
# VMail Message       int64
# Day Mins          float64
# Day Calls           int64
# Day Charge        float64
# Eve Mins          float64
# Eve Calls           int64
# Eve Charge        float64
# Night Mins        float64
# Night Calls         int64
# Night Charge      float64
# Intl Mins         float64
# Intl Calls          int64
# Intl Charge       float64
# CustServ Calls      int64
# Churn?             object
# Total Minutes       int64
# dtype: object

# %% [markdown]
# And that column value based on the sum of day, night calls together

# %%
df['Total Minutes'] = df['Day Mins'] + df['Eve Mins'] + df['Night Mins']
df.head(2)
# Out:
#   Customer State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    A1001    KS           128.0        415  382-4657         no        NaN
# 1    A1002    OH           107.0        415  371-7191         no        NaN
#
#    VMail Message  Day Mins  Day Calls  ...  Eve Charge  Night Mins  \
# 0             25     265.1        110  ...       16.78       244.7
# 1             26     161.6        123  ...       16.62       254.4
#
#    Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0           91         11.01       10.0           3          2.7
# 1          103         11.45       13.7           3          3.7
#
#    CustServ Calls  Churn?  Total Minutes
# 0               1  False.          707.2
# 1               1  False.          611.5
#
# [2 rows x 23 columns]

# %% [markdown]
# Rename the column name to another name

# %%
df.rename(columns={'Total Minutes' : 'Total Mins'},inplace=True)

# %% [markdown]
# Delete one of the column

# %%
df.drop(columns=['Total Mins'], inplace=True)

# %% [markdown]
# Sort the records based on one or multiple columns

# %%
df.sort_values(by=['State'])
# Out:
#      Customer State  Account Length  Area Code     Phone Int'l Plan  \
# 181     A1182    AK           126.0        415  372-3750         no
# 550     A1551    AK           111.0        415  364-7719         no
# 2929    A3930    AK            71.0        510  332-2275         no
# 1260    A2261    AK            76.0        415  366-9781         no
# 1803    A2804    AK           101.0        510  411-4940         no
# 1054    A2055    AK            50.0        408  362-8331         no
# 138     A1139    AK           127.0        510  345-8237         no
# 3088    A4089    AK           100.0        415  394-5202         no
# 3137    A4138    AK            58.0        510  364-1134         no
# 95      A1096    AK           104.0        408  366-4467         no
# 2475    A3476    AK             1.0        408  373-1028         no
# 718     A1719    AK           127.0        408  383-9255         no
# 719     A1720    AK            78.0        510  418-9385         no
# ...

# %% [markdown]
# Sort the records based on the index

# %%
df.sort_index()
# Out:
#      Customer State  Account Length  Area Code     Phone Int'l Plan  \
# 0       A1001    KS           128.0        415  382-4657         no
# 1       A1002    OH           107.0        415  371-7191         no
# 2       A1003    NJ           137.0        415  358-1921         no
# 3       A1004    OH            84.0        408  375-9999        yes
# 4       A1005    OK            75.0        415  330-6626        yes
# 5       A1006    AL             NaN        510  391-8027        yes
# 6       A1007    MA             NaN        510  355-9993         no
# 7       A1008    MO           147.0        415  329-9001        yes
# 8       A1009    LA           117.0        408  335-4719         no
# 9       A1010    WV           141.0        415  330-8173        yes
# 10      A1011    IN             NaN        415  329-6603         no
# 11      A1012    RI            74.0        415  344-9403         no
# 12      A1013    IA           168.0        408  363-1107         no
# ...

# %% [markdown]
# Count the number of records that has the State as AL OR NJ

# %%
df[(df.State == 'AL') | (df.State == 'NJ')].size
# Out:
# 3256

# %% [markdown]
# Find out how many International plan holders who have churned.

# %%
df[(df['Int\'l Plan'] == 'yes') & (df['Churn?'] == 'True.')]
# Out:
#      Customer State  Account Length  Area Code     Phone Int'l Plan  \
# 41      A1042    MD           135.0        408  383-6029        yes
# 115     A1116    ME            36.0        510  363-1069        yes
# 144     A1145    VT           117.0        408  390-2390        yes
# 198     A1199    ME           131.0        510  353-7292        yes
# 214     A1215    FL            70.0        510  366-6345        yes
# 230     A1231    MD            93.0        408  360-3324        yes
# 241     A1242    NV           137.0        415  338-1027        yes
# 258     A1259    KS            92.0        408  386-4170        yes
# 319     A1320    SD           128.0        510  413-9269        yes
# 354     A1355    MS            64.0        408  402-1942        yes
# 360     A1361    CO           159.0        408  341-4463        yes
# 372     A1373    CA           151.0        415  357-1909        yes
# 378     A1379    MO            95.0        415  374-7787        yes
# ...

# %% [markdown]
# Find out how many na records in the entired data set

# %%
df['Account Length'].isna().sum()
# Out:
# 3

# %% [markdown]
# How many are not na in the VMail Plan

# %%
df['VMail Plan'].notna().sum()
# Out:
# 3331

# %% [markdown]
# Which Area code have churned maximum?

# %%
df[df['Churn?'] == 'True.']['Area Code'].value_counts().max()
# Out:
# 236

# %% [markdown]
# How many of Internation plan holders belong to State - AL and NJ?

# %%
df[df['Int\'l Plan'] == 'yes'][(df['State'] == 'AL') | (df['State'] == 'NJ')]
# Out:
# C:\Users\XPS\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      Customer State  Account Length  Area Code     Phone Int'l Plan  \
# 5       A1006    AL             NaN        510  391-8027        yes
# 135     A1136    AL            91.0        510  387-2919        yes
# 491     A1492    AL            55.0        415  375-2975        yes
# 514     A1515    AL            60.0        408  411-7778        yes
# 626     A1627    NJ            95.0        408  348-8015        yes
# 734     A1735    NJ            93.0        415  328-1768        yes
# 1428    A2429    AL            96.0        415  410-5455        yes
# 1662    A2663    AL           197.0        415  395-7923        yes
# 1757    A2758    NJ            42.0        408  342-8002        yes
# 1903    A2904    NJ            93.0        510  384-5632        yes
# ...

# %%
df[(df['Int\'l Plan'] == 'yes') & (df['State'].isin(['AL','NJ']))]
# Out:
#      Customer State  Account Length  Area Code     Phone Int'l Plan  \
# 5       A1006    AL             NaN        510  391-8027        yes
# 135     A1136    AL            91.0        510  387-2919        yes
# 491     A1492    AL            55.0        415  375-2975        yes
# 514     A1515    AL            60.0        408  411-7778        yes
# 626     A1627    NJ            95.0        408  348-8015        yes
# 734     A1735    NJ            93.0        415  328-1768        yes
# 1428    A2429    AL            96.0        415  410-5455        yes
# 1662    A2663    AL           197.0        415  395-7923        yes
# 1757    A2758    NJ            42.0        408  342-8002        yes
# 1903    A2904    NJ            93.0        510  384-5632        yes
# 2293    A3294    NJ            59.0        510  347-5354        yes
# 2526    A3527    NJ            57.0        510  330-2635        yes
# 2845    A3846    AL            19.0        415  380-3910        yes
# ...
